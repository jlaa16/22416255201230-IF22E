# %%
import matplotlib.pyplot as plt

x_values = [1,2,3,4,5]
y_values = [10,12,5,8,15]

plt.plot(x_values,y_values)
plt.xlabels('x-axis')
plt.ylabels('y-axis')
plt.title("scatter plot example")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 7
#       4 y_values = [10,12,5,8,15]
#       6 plt.plot(x_values,y_values)
# ----> 7 plt.xlabels('x-axis')
#       8 plt.ylabels('y-axis')
#       9 plt.title("scatter plot example")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlabels'
