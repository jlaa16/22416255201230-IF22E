# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# Memuat data iris
iris = load_iris()
x = iris.data
y = iris.target

# Memisahkan data menjadi data training dan testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Membangun model pohon keputusan
dt_classifier = DecisionTreeClassifier(random_state=42)
dt_classifier.fit(x_train, y_train)

# Membuat prediksi
y_pred = dt_classifier.predict(x_test)

# Evaluasi model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Visualisasi pohon keputusan
plt.figure(figsize=(12, 8))  # Corrected the function name
plot_tree(dt_classifier, filled=True, feature_names=iris.feature_names)  # Corrected the function name
plt.show()
# Out:
# Accuracy: 1.00
